# %%
# Find split of dataset
lbls_split = []
with open("datasetSplit.txt","r") as f:
    next(f)
    for line in f:
        [_, id_split] = line.strip().split(',')
        lbls_split.append(eval(id_split))
# Split dataset
words_train = []
sents_train = []
words_test = []
sents_test = []
with open("SOStr.txt","r") as f:
    for i, line in enumerate(f):
        if lbls_split[i] is 1:
            words_train.append(line.strip().split('|'))
            sents_train.append(line.strip().replace('|', ' '))
        elif lbls_split[i] is 2:
            words_test.append(line.strip().split('|'))
            sents_test.append(line.strip().replace('|', ' '))
# Extract word/sentency dictionary
dct = []
ids_dct = []
with open('dictionary.txt') as f:
    for line in f:
        line = line.strip()
        index = line.find('|')
        word, num = line.split('|')
        dct.append(word)
        ids_dct.append(eval(num))
# Extract ratings
ratings = []
with open('sentiment_labels.txt') as f:
    next(f)
    for line in f:
        [_, rate] = line.strip().split('|')
        ratings.append(eval(rate))
# Extract dataset labels
# Training
lbls_train = []
for sent in sents_train:
    rating = ratings[ids_dct[dct.index(sent)]]
    if rating >= 0 and rating < 0.2:
        lbls_train.append(0)
    elif rating >= 0.2 and rating < 0.4:
        lbls_train.append(1)
    elif rating >= 0.4 and rating < 0.6:
        lbls_train.append(2)
    elif rating >= 0.6 and rating < 0.8:
        lbls_train.append(3)
    elif rating >= 0.8 and rating <= 1:
        lbls_train.append(4)
# Testing
lbls_test = []
for sent in sents_test:
    rating = ratings[ids_dct[dct.index(sent)]]
    if rating >= 0 and rating < 0.2:
        lbls_test.append(0)
    elif rating >= 0.2 and rating < 0.4:
        lbls_test.append(1)
    elif rating >= 0.4 and rating < 0.6:
        lbls_test.append(2)
    elif rating >= 0.6 and rating < 0.8:
        lbls_test.append(3)
    elif rating >= 0.8 and rating <= 1:
        lbls_test.append(4)

# %%
# Smoothing variable
k = .001
# Calculate probabilities
Py = [0]*5

Pwgy = [dict(), dict(), dict(), dict(), dict()]
for w, words in enumerate(words_train):
    # Sentiment probability
    Py[lbls_train[w]] += 1
    for word in words:
        # Probability of word given sentiment
        if not word in Pwgy[lbls_train[w]]:
            Pwgy[lbls_train[w]][word] = k * Py[lbls_train[w]]
        Pwgy[lbls_train[w]][word] += 1
nwords = [k]*5
for y in range(0, len(Py)):
    Py[y] /= len(sents_train)
for w, words in enumerate(words_train):
    for word in words:
        nwords[lbls_train[w]] += 1
for y in range(0, len(Pwgy)):
    Pwgy[y][_] = k
    for word in Pwgy[y]:
        Pwgy[y][word] /= nwords[y]

# %%
print('Performance Using All Observed Words')
# Predict probabilities
Pygw = [0]*5
# Make predictions
# Training
classification_matrix_train = [[0 for j in range(5)] for i in range(5)]
diff_sum = 0
corr = 0
for s, sent in enumerate(sents_train):
    # Probability of sentiment given sentence
    Pw = 0
    for y in range(0, len(Py)):
        Pwgy_prod = 1
        for word in words_train[s]:
            if word in Pwgy[y]:
                Pwgy_prod *= Pwgy[y][word]
            else:
                Pwgy_prod *= Pwgy[y][_]
        Pygw[y] = Py[y]*Pwgy_prod
        Pw += Pygw[y]
    for y in range(0, len(Py)):
        Pygw[y] /= Pw
    classification_matrix_train[lbls_train[s]][Pygw.index(max(Pygw))] += 1
    diff_sum += (lbls_train[s] - Pygw.index(max(Pygw))) ** 2
    if Pygw.index(max(Pygw)) == lbls_train[s]:
        corr += 1
perf_train = corr/len(sents_train)*100
std_dev = (diff_sum/len(sents_train)) ** .5
print('Training Performance: {0:.2f}%'.format(perf_train))
print('Training Std Dev: {}'.format(std_dev))
for i in range(5):
    for j in range(5):
        print('Number with correct label {} classified as {}: {}'.format(i,j,classification_matrix_train[i][j]))
    print()

# Testing
corr = 0
diff_sum = 0
classification_matrix = [[0 for j in range(5)] for i in range(5)]
for s, sent in enumerate(sents_test):
    # Probability of sentiment given sentence
    Pw = 0
    for y in range(0, len(Py)):
        Pwgy_prod = 1
        for word in words_test[s]:
            if word in Pwgy[y]:
                Pwgy_prod *= Pwgy[y][word]
            else:
                Pwgy_prod *= Pwgy[y][_]
        Pygw[y] = Py[y]*Pwgy_prod
        Pw += Pygw[y]
    for y in range(0, len(Py)):
        Pygw[y] /= Pw
    classification_matrix[lbls_test[s]][Pygw.index(max(Pygw))] += 1
    diff_sum += (lbls_test[s] - Pygw.index(max(Pygw))) ** 2
    if Pygw.index(max(Pygw)) == lbls_test[s]:
        corr += 1
perf_test = corr/len(sents_test)*100
std_dev = (diff_sum/len(sents_test)) ** .5
print('Testing Performance: {0:.2f}%'.format(perf_test))
print('Testing Std Dev: {}'.format(std_dev))
for i in range(5):
    for j in range(5):
        print('Number with correct label {} classified as {}: {}'.format(i,j,classification_matrix[i][j]))
    print()
# Out:
# Performance Using All Observed Words
# Training Performance: 92.65%
# Training Std Dev: 0.42011680202156154
# Number with correct label 0 classified as 0: 1029
# Number with correct label 0 classified as 1: 41
# Number with correct label 0 classified as 2: 14
# Number with correct label 0 classified as 3: 6
# Number with correct label 0 classified as 4: 2
#
# Number with correct label 1 classified as 0: 69
# Number with correct label 1 classified as 1: 2061
# Number with correct label 1 classified as 2: 52
# Number with correct label 1 classified as 3: 28
# Number with correct label 1 classified as 4: 8
#
# Number with correct label 2 classified as 0: 20
# Number with correct label 2 classified as 1: 69
# Number with correct label 2 classified as 2: 1476
# Number with correct label 2 classified as 3: 43
# Number with correct label 2 classified as 4: 16
#
# Number with correct label 3 classified as 0: 12
# Number with correct label 3 classified as 1: 50
# Number with correct label 3 classified as 2: 46
# Number with correct label 3 classified as 3: 2132
# Number with correct label 3 classified as 4: 82
#
# Number with correct label 4 classified as 0: 7
# Number with correct label 4 classified as 1: 12
# Number with correct label 4 classified as 2: 19
# Number with correct label 4 classified as 3: 32
# Number with correct label 4 classified as 4: 1218
#
# Testing Performance: 35.48%
# Testing Std Dev: 1.3287629057617867
# Number with correct label 0 classified as 0: 75
# Number with correct label 0 classified as 1: 114
# Number with correct label 0 classified as 2: 46
# Number with correct label 0 classified as 3: 31
# Number with correct label 0 classified as 4: 13
#
# Number with correct label 1 classified as 0: 104
# Number with correct label 1 classified as 1: 260
# Number with correct label 1 classified as 2: 145
# Number with correct label 1 classified as 3: 92
# Number with correct label 1 classified as 4: 32
#
# Number with correct label 2 classified as 0: 54
# Number with correct label 2 classified as 1: 105
# Number with correct label 2 classified as 2: 98
# Number with correct label 2 classified as 3: 100
# Number with correct label 2 classified as 4: 32
#
# Number with correct label 3 classified as 0: 22
# Number with correct label 3 classified as 1: 96
# Number with correct label 3 classified as 2: 71
# Number with correct label 3 classified as 3: 211
# Number with correct label 3 classified as 4: 110
#
# Number with correct label 4 classified as 0: 12
# Number with correct label 4 classified as 1: 40
# Number with correct label 4 classified as 2: 47
# Number with correct label 4 classified as 3: 160
# Number with correct label 4 classified as 4: 140

# %%
# Extract known positive and negative words
words_pos = []
with open('positive-words.txt', 'r', encoding = 'latin-1') as f:
    for i in range(0, 35):
        next(f)
    for line in f:
        words_pos.append(line.strip())
words_neg = []
with open('negative-words.txt', 'r', encoding = 'latin-1') as f:
    for i in range(0, 35):
        next(f)
    for line in f:
        words_neg.append(line.strip())

# %%
# Smoothing variable
k = .01
# Calculate probabilities
Py = [0]*5
Pwgy = [dict(), dict(), dict(), dict(), dict()]
for w, words in enumerate(words_train):
    # Sentiment probability
    Py[lbls_train[w]] += 1
    for word in words:
        # Probability of word given sentiment
        if word.casefold() in words_pos or word.casefold() in words_neg:
            if not word in Pwgy[lbls_train[w]]:
                Pwgy[lbls_train[w]][word] = k
            Pwgy[lbls_train[w]][word] += 1
for y in range(0, len(Py)):
    Py[y] /= len(sents_train)
nwords = [k]*5
for w, words in enumerate(words_train):
    for word in words:
        if word.casefold() in words_pos or word.casefold() in words_neg:
            nwords[lbls_train[w]] += 1
for y in range(0, len(Pwgy)):
    Pwgy[y][_] = k
    for word in Pwgy[y]:
        Pwgy[y][word] /= nwords[y]

# %%
print('Performance Using Only Known Words')
# Predict probabilities
Pygw = [0]*5
# Make predictions
# Training
classification_matrix_train = [[0 for j in range(5)] for i in range(5)]
diff_sum = 0
corr = 0
for s, sent in enumerate(sents_train):
    # Probability of sentiment given sentence
    Pw = 0
    for y in range(0, len(Py)):
        Pwgy_prod = 1
        for word in words_train[s]:
            if word in Pwgy[y]:
                Pwgy_prod *= Pwgy[y][word]
            else:
                Pwgy_prod *= Pwgy[y][_]
        Pygw[y] = Py[y]*Pwgy_prod
        Pw += Pygw[y]
    for y in range(0, len(Py)):
        Pygw[y] /= Pw
    classification_matrix_train[lbls_train[s]][Pygw.index(max(Pygw))] += 1
    diff_sum += (lbls_train[s] - Pygw.index(max(Pygw))) ** 2
    if Pygw.index(max(Pygw)) == lbls_train[s]:
        corr += 1
perf_train = corr/len(sents_train)*100
std_dev = (diff_sum/len(sents_train)) ** .5
print('Training Performance: {0:.2f}%'.format(perf_train))
print('Training Std Dev: {}'.format(std_dev))
for i in range(5):
    for j in range(5):
        print('Number with correct label {} classified as {}: {}'.format(i,j,classification_matrix_train[i][j]))
    print()

# Testing
corr = 0
diff_sum = 0
classification_matrix = [[0 for j in range(5)] for i in range(5)]
for s, sent in enumerate(sents_test):
    # Probability of sentiment given sentence
    Pw = 0
    for y in range(0, len(Py)):
        Pwgy_prod = 1
        for word in words_test[s]:
            if word in Pwgy[y]:
                Pwgy_prod *= Pwgy[y][word]
            else:
                Pwgy_prod *= Pwgy[y][_]
        Pygw[y] = Py[y]*Pwgy_prod
        Pw += Pygw[y]
    for y in range(0, len(Py)):
        Pygw[y] /= Pw
    classification_matrix[lbls_test[s]][Pygw.index(max(Pygw))] += 1
    diff_sum += (lbls_test[s] - Pygw.index(max(Pygw))) ** 2
    if Pygw.index(max(Pygw)) == lbls_test[s]:
        corr += 1
perf_test = corr/len(sents_test)*100
std_dev = (diff_sum/len(sents_test)) ** .5
print('Testing Performance: {0:.2f}%'.format(perf_test))
print('Testing Std Dev: {}'.format(std_dev))
for i in range(5):
    for j in range(5):
        print('Number with correct label {} classified as {}: {}'.format(i,j,classification_matrix[i][j]))
    print()
# Out:
# Performance Using Only Known Words
# Training Performance: 30.72%
# Training Std Dev: 1.840935888025497
# Number with correct label 0 classified as 0: 1089
# Number with correct label 0 classified as 1: 0
# Number with correct label 0 classified as 2: 3
# Number with correct label 0 classified as 3: 0
# Number with correct label 0 classified as 4: 0
#
# Number with correct label 1 classified as 0: 1799
# Number with correct label 1 classified as 1: 139
# Number with correct label 1 classified as 2: 230
# Number with correct label 1 classified as 3: 0
# Number with correct label 1 classified as 4: 50
#
# Number with correct label 2 classified as 0: 971
# Number with correct label 2 classified as 1: 0
# Number with correct label 2 classified as 2: 630
# Number with correct label 2 classified as 3: 0
# Number with correct label 2 classified as 4: 23
#
# Number with correct label 3 classified as 0: 1477
# Number with correct label 3 classified as 1: 6
# Number with correct label 3 classified as 2: 411
# Number with correct label 3 classified as 3: 107
# Number with correct label 3 classified as 4: 321
#
# Number with correct label 4 classified as 0: 494
# Number with correct label 4 classified as 1: 0
# Number with correct label 4 classified as 2: 134
# Number with correct label 4 classified as 3: 0
# Number with correct label 4 classified as 4: 660
#
# Testing Performance: 19.68%
# Testing Std Dev: 2.0112804053085886
# Number with correct label 0 classified as 0: 247
# Number with correct label 0 classified as 1: 5
# Number with correct label 0 classified as 2: 26
# Number with correct label 0 classified as 3: 1
# Number with correct label 0 classified as 4: 0
#
# Number with correct label 1 classified as 0: 527
# Number with correct label 1 classified as 1: 8
# Number with correct label 1 classified as 2: 81
# Number with correct label 1 classified as 3: 1
# Number with correct label 1 classified as 4: 16
#
# Number with correct label 2 classified as 0: 297
# Number with correct label 2 classified as 1: 0
# Number with correct label 2 classified as 2: 67
# Number with correct label 2 classified as 3: 0
# Number with correct label 2 classified as 4: 25
#
# Number with correct label 3 classified as 0: 318
# Number with correct label 3 classified as 1: 4
# Number with correct label 3 classified as 2: 106
# Number with correct label 3 classified as 3: 4
# Number with correct label 3 classified as 4: 78
#
# Number with correct label 4 classified as 0: 212
# Number with correct label 4 classified as 1: 3
# Number with correct label 4 classified as 2: 74
# Number with correct label 4 classified as 3: 1
# Number with correct label 4 classified as 4: 109
